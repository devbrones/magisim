# %% [markdown]
# # 06. GRIN medium and analysing refraction
#
# submitted by [substancia](https://github.com/substancia), adapted by [flaport](https://github.com/flaport)

# %% [markdown]
# ## Imports

# %%
import os
import fdtd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grid

# %%
fdtd.set_backend("torch.cuda.float64")
grid = fdtd.Grid(shape=(9.3e-6, 15.5e-6, 1), grid_spacing=77.5e-9)
# x boundaries
grid[0:10, :, :] = fdtd.PML(name="pml_xlow")
grid[-10:, :, :] = fdtd.PML(name="pml_xhigh")
# y boundaries
grid[:, 0:10, :] = fdtd.PML(name="pml_ylow")
grid[:, -10:, :] = fdtd.PML(name="pml_yhigh")
simfolder = grid.save_simulation("GRIN")  # initializing environment to save simulation data
print(simfolder)
# Out:
# /home/tb/repos/magisim/src/tests/fdtd_output/fdtd_output_2023-12-1-12-35-14 (GRIN)

# %% [markdown]
# ## Objects
# defining a graded refractive index slab, with homogenous slab extensions outwards from both ends

# %%
n0, theta, t = 1, 30, 0.5
for i in range(50):
    x = i * 0.08
    epsilon = n0 + x * np.sin(np.radians(theta)) / t
    epsilon = epsilon ** 0.5
    grid[
        5.1e-6:5.6e-6, (5 + i * 0.08) * 1e-6 : (5.08 + i * 0.08) * 1e-6, 0
    ] = fdtd.Object(permittivity=epsilon, name="object" + str(i))

# homogenous slab extensions
grid[5.1e-6:5.6e-6, 0.775e-6:5e-6, 0] = fdtd.Object(
    permittivity=n0 ** 2, name="objectLeft"
)
grid[5.1e-6:5.6e-6, 9e-6 : (15.5 - 0.775) * 1e-6, 0] = fdtd.Object(
    permittivity=epsilon, name="objectRight"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     epsilon = n0 + x * np.sin(np.radians(theta)) / t
#       <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     epsilon = epsilon ** 0.5
# ----> <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     grid[
#       <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>         5.1e-6:5.6e-6, (5 + i * 0.08) * 1e-6 : (5.08 + i * 0.08) * 1e-6, 0
#       <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     ] = fdtd.Object(permittivity=epsilon, name="object" + str(i))
#      <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> # homogenous slab extensions
#      <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> grid[5.1e-6:5.6e-6, 0.775e-6:5e-6, 0] = fdtd.Object(
#      <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>     permittivity=n0 ** 2, name="objectLeft"
#      <a href='vscode-notebook-cell:/home/tb/repos/magisim/src/tests/06-GRIN-medium-and-analysing-refraction.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a> )
#
# File ~/anaconda3/envs/msimdev/lib/python3.9/site-packages/fdtd/grid.py:370, in Grid.__setitem__(self, key, attr)
#     367 else:
#     368     raise KeyError("maximum number of indices for the grid is 3")
# --> 370 attr._register_grid(
#     371     grid=self,
#     372     x=self._handle_single_key(x),
#     373     y=self._handle_single_key(y),
#     374     z=self._handle_single_key(z),
#     375 )
#
# File ~/anaconda3/envs/msimdev/lib/python3.9/site-packages/fdtd/objects.py:73, in Object._register_grid(self, grid, x, y, z)
#      70 if bd.is_array(self.permittivity) and len(self.permittivity.shape) == 3:
#      71     self.permittivity = self.permittivity[:, :, :, None]
#      72 self.inverse_permittivity = (
# ---> 73     bd.ones((self.Nx, self.Ny, self.Nz, 3), dtype=self.permittivity.dtype)
#      74     / self.permittivity
#      75 )
#      77 # set the permittivity values of the object at its border to be equal
#      78 # to the grid permittivity. This way, the object is made symmetric.
#      79 if self.Nx > 1:
#
# TypeError: ones() got an unexpected keyword argument 'dtype'

# %% [markdown]
# ## Source
# using a pulse (hanning window pulse)

# %%
grid[3.1e-6, 1.5e-6:14e-6, 0] = fdtd.LineSource(period=1550e-9 / (3e8), name="source", pulse=True, cycle=3, hanning_dt=4e-15)

# %% [markdown]
# ## Detectors
# using a linear array of LineDetector

# %%
for i in range(-4, 8):
    grid[5.8e-6, 84 + 4 * i : 86 + 4 * i, 0] = fdtd.LineDetector(name="detector" + str(i))

# %% [markdown]
# ## Saving grid geometry

# %%
with open(os.path.join("./fdtd_output", grid.folder, "grid.txt"), "w") as f:
    f.write(str(grid))
    wavelength = 3e8/grid.source.frequency
    wavelengthUnits = wavelength/grid.grid_spacing
    GD = np.array([grid.x, grid.y, grid.z])
    gridRange = [np.arange(x/grid.grid_spacing) for x in GD]
    objectRange = np.array([[gridRange[0][x.x], gridRange[1][x.y], gridRange[2][x.z]] for x in grid.objects], dtype=object).T
    f.write("\n\nGrid details (in wavelength scale):")
    f.write("\n\tGrid dimensions: ")
    f.write(str(GD/wavelength))
    f.write("\n\tSource dimensions: ")
    f.write(str(np.array([grid.source.x[-1] - grid.source.x[0] + 1, grid.source.y[-1] - grid.source.y[0] + 1, grid.source.z[-1] - grid.source.z[0] + 1])/wavelengthUnits))
    f.write("\n\tObject dimensions: ")
    f.write(str([(max(map(max, x)) - min(map(min, x)) + 1)/wavelengthUnits for x in objectRange]))

# %% [markdown]
# ## Simulation

# %%
from IPython.display import clear_output  # only necessary in jupyter notebooks

for i in range(100):
    grid.step()  # running simulation 1 timestep a time and animating
    if i % 5 == 0:
        # saving frames during visualization
        grid.visualize(z=0, animate=True, index=i, save=True, folder=simfolder)
        plt.title(f"{i:3.0f}")
        clear_output(wait=True)  # only necessary in jupyter notebooks
grid.save_data()  # saving detector readings

# %% [markdown]
# We can generate a video with ffmpeg:

# %%
try:
    video_path = grid.generate_video(delete_frames=False)  # rendering video from saved frames
except:
    video_path = ""
    print("ffmpeg not installed?")
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'file%04d.png':
#   Duration: 00:00:00.13, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 640x480 [SAR 3937:3937 DAR 4:3], 8 tbr, 8 tbn, 8 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x555d0f6f44c0] using SAR=1/1
# [libx264 @ 0x555d0f6f44c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x555d0f6f44c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x555d0f6f44c0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'fdtd_sim_video_2023-11-10-10-28-42 (GRIN).mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480 [SAR 1:1 DAR 4:3], q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=    4 fps=0.0 q=-1.0 Lsize=       7kB time=00:00:00.03 bitrate=1744.3kbits/s dup=3 drop=0 speed=2.23x
# video:6kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 13.959311%
# [libx264 @ 0x555d0f6f44c0] frame I:1     Avg QP:23.36  size:  5520
# [libx264 @ 0x555d0f6f44c0] frame P:1     Avg QP:14.00  size:    81
# [libx264 @ 0x555d0f6f44c0] frame B:2     Avg QP:13.50  size:    56
# [libx264 @ 0x555d0f6f44c0] consecutive B-frames: 25.0%  0.0% 75.0%  0.0%
# [libx264 @ 0x555d0f6f44c0] mb I  I16..4: 40.2% 44.2% 15.5%
# [libx264 @ 0x555d0f6f44c0] mb P  I16..4:  2.8%  0.0%  0.0%  P16..4:  0.4%  0.1%  0.0%  0.0%  0.0%    skip:96.7%
# [libx264 @ 0x555d0f6f44c0] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  3.3%  0.0%  0.0%  direct: 0.0%  skip:96.6%  L0: 6.3% L1:93.7% BI: 0.0%
# [libx264 @ 0x555d0f6f44c0] 8x8 transform intra:43.0%
# [libx264 @ 0x555d0f6f44c0] coded y,uvDC,uvAC intra: 7.5% 3.7% 1.9% inter: 0.0% 0.0% 0.0%
# [libx264 @ 0x555d0f6f44c0] i16 v,h,dc,p: 42% 52%  6%  0%
# [libx264 @ 0x555d0f6f44c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 29% 47%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x555d0f6f44c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 35% 11%  1%  1%  2%  2%  2%  2%
# [libx264 @ 0x555d0f6f44c0] i8c dc,h,v,p: 77% 18%  5%  0%
# [libx264 @ 0x555d0f6f44c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x555d0f6f44c0] kb/s:342.84

# %%
if video_path:
    from IPython.display import Video
    display(Video(video_path, embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Analyse
# analysing data stored by above simulation to find intensity profile and time-of-arrival plot

# %%
dic = np.load(os.path.join(simfolder, "detector_readings.npz"))
import warnings; warnings.filterwarnings("ignore") # TODO: fix plot_detection to prevent warnings
fdtd.plot_detection(dic)
